# %%
from pandas import DataFrame, read_table
import pandas as pd

# %%
R_pal_file = "R_pal_metadata_df.txt"
df_input = pd.read_table(R_pal_file, sep="\t")

#after reading in the meta-data table, you always have to keep only the rows you want
# and then remove duplicates.
to_keep_meta = ['RefSeq', 'Essential_aerobic', 'Essential_phototrophic', 'Essential_longevity', 
                'gene_product', 'Pfam_name', 'locus']
df_temp = df_input[to_keep_meta]
df = df_temp.drop_duplicates()

# %%
##### Identify PFams of unknown function
# Trying to identify if something has an UNKNOWN functional annotation
# put is some grep hacks: DUF from pfam or 'hypothetical' in the gene name

Unknowns_array = [] # I am using this iterator instead of apply because
#there are things with multiple pfams, and so they have multiple rows
# I was not sure how to properly condense something when the two rows
# of a protein may have two different answers. So here I am making a single
#array and then joining it back.

for index, row in df.iterrows():
    if pd.isnull(row['Pfam_name']): # some things don't have a pfam,
        continue # skip these things,
    Pfam = row['Pfam_name']
    if Pfam[:3] == 'DUF':
        locus = row['locus']
        Unknowns_array.append({'locus':locus, 'characterized_function':False})

for index, row in df.iterrows():
    gene = row['gene_product']
    locus = row['locus']
    if 'hypothetical' in gene:
        Unknowns_array.append({'locus':locus, 'characterized_function':False})

#now we non-redundify the list, as it may get the same locus from both 6.1 and 6.2
df_temp = pd.DataFrame(data=Unknowns_array)
df_temp.drop_duplicates(inplace=True)

#merge back
df = df.merge(df_temp, left_on='locus', right_on='locus', how='left')
#now the tricky part. all the things which ARE functionally defined were absent in df_temp
# so they are now 'NaN' or the default NULL for merge. These have to be changed back to 'True'
# meaning that yes, they do have a known function.
df['characterized_function'].fillna(True, inplace=True)

# %%
df
# Out:
#               RefSeq  Essential_aerobic  Essential_phototrophic  \
# 0     WP_011155572.1               True                   False
# 1     WP_011155573.1               True                   False
# 2     WP_042440644.1              False                   False
# 3     WP_011155575.1               True                   False
# 4     WP_011155576.1              False                   False
# 5     WP_011155577.1              False                   False
# 6     WP_011155578.1              False                   False
# 7     WP_011155578.1              False                   False
# 8     WP_011155578.1              False                   False
# 9     WP_011155579.1              False                   False
# 10    WP_011155580.1              False                   False
# 11    WP_011155581.1              False                   False
# 12    WP_011155581.1              False                   False
# 13    WP_011155582.1              False                   False
# 14    WP_011155583.1              False                   False
# 15    WP_011155584.1               True                   False
# 16    WP_042441354.1               True                   False
# 17    WP_011155586.1              False                   False
# 18    WP_011155587.1               True                   False
# 19    WP_011155588.1               True                   False
# 20    WP_011155589.1               True                   False
# 21    WP_011155590.1              False                   False
# 22    WP_011155591.1              False                   False
# 23    WP_011155592.1              False                   False
# 24    WP_085977279.1              False                   False
# 25    WP_042440651.1              False                   False
# 26    WP_011155595.1              False                   False
# 27    WP_011155596.1              False                   False
# 28    WP_011155597.1              False                   False
# 29    WP_011155598.1              False                   False
# ...              ...                ...                     ...
# 5357  WP_011160343.1              False                   False
# 5358  WP_011160344.1              False                   False
# 5359  WP_011160345.1              False                   False
# 5360  WP_011160346.1              False                   False
# 5361  WP_011160346.1              False                   False
# 5362  WP_011160347.1              False                   False
# 5363  WP_011160348.1              False                   False
# 5364  WP_011160349.1              False                   False
# 5365  WP_011160349.1              False                   False
# 5366  WP_011160350.1              False                   False
# 5367  WP_011160351.1              False                   False
# 5368  WP_011160352.1              False                   False
# 5369  WP_011160353.1              False                   False
# 5370  WP_042441352.1              False                   False
# 5371  WP_011160355.1              False                   False
# 5372  WP_011160355.1              False                   False
# 5373  WP_011160356.1              False                   False
# 5374  WP_011160357.1              False                   False
# 5375  WP_011160358.1              False                   False
# 5376  WP_011160359.1              False                   False
# 5377  WP_011160360.1              False                   False
# 5378  WP_011160361.1              False                   False
# 5379  WP_012497922.1              False                   False
# 5380  WP_011160363.1               True                   False
# 5381  WP_011160364.1              False                   False
# 5382  WP_011160365.1              False                   False
# 5383  WP_011160365.1              False                   False
# 5384  WP_011160366.1              False                   False
# 5385  WP_011160367.1              False                   False
# 5386  WP_011160368.1               True                   False
#
#       Essential_longevity                                       gene_product  \
# 0                   False     chromosomal replication initiator protein DnaA
# 1                   False                    DNA polymerase III subunit beta
# 2                   False            DNA replication and repair protein RecF
# 3                   False      DNA topoisomerase (ATP-hydrolyzing) subunit B
# 4                   False                4-hydroxyphenylpyruvate dioxygenase
# 5                   False          Lrp/AsnC family transcriptional regulator
# 6                   False                                   histidine kinase
# 7                   False                                   histidine kinase
# 8                   False                                   histidine kinase
# 9                   False                                             KaiB 1
# 10                  False                       circadian clock protein KaiC
# 11                  False          Lrp/AsnC family transcriptional regulator
# 12                  False          Lrp/AsnC family transcriptional regulator
# 13                  False                               hypothetical protein
# 14                  False  cbb3-type cytochrome oxidase assembly protein ...
# 15                  False                 copper-translocating P-type ATPase
# 16                  False                     nitrogen fixation protein FixH
# 17                  False        cytochrome c oxidase accessory protein CcoG
# 18                  False        cytochrome-c oxidase, cbb3-type subunit III
# 19                  False  CcoQ/FixQ family Cbb3-type cytochrome c oxidas...
# 20                  False         cytochrome-c oxidase, cbb3-type subunit II
# 21                  False          cytochrome-c oxidase, cbb3-type subunit I
# 22                  False                      2-dehydropantoate 2-reductase
# 23                  False                          short-chain dehydrogenase
# 24                  False          2-hydroxychromene-2-carboxylate isomerase
# 25                  False                          glutathione S-transferase
# 26                  False                          short chain dehydrogenase
# 27                  False                          gamma-glutamyltransferase
# 28                   True                                    MFS transporter
# 29                  False              3-deoxy-7-phosphoheptulonate synthase
# ...                   ...                                                ...
# 5357                False                      iron ABC transporter permease
# 5358                False                               MAPEG family protein
# 5359                False                           ABC transporter permease
# 5360                False                                   membrane protein
# 5361                False                                   membrane protein
# 5362                False                           molecular chaperone HtpG
# 5363                False                            sensor histidine kinase
# 5364                False                     DNA-binding response regulator
# 5365                False                     DNA-binding response regulator
# 5366                 True                                          peptidase
# 5367                False                               hypothetical protein
# 5368                False        S-methyl-5-thioribose-1-phosphate isomerase
# 5369                False            S-methyl-5'-thioadenosine phosphorylase
# 5370                False                            maleylacetate reductase
# 5371                False                                acyl-CoA synthetase
# 5372                False                                acyl-CoA synthetase
# 5373                 True                              EthD family reductase
# 5374                False              MerR family transcriptional regulator
# 5375                False                                  DNA helicase RecQ
# 5376                False              zinc ribbon domain-containing protein
# 5377                False                  DUF3551 domain-containing protein
# 5378                False                crotonobetaine/carnitine-CoA ligase
# 5379                False                                   phosphohydrolase
# 5380                False                               hypothetical protein
# 5381                False              dienelactone hydrolase family protein
# 5382                False                polysaccharide biosynthesis protein
# 5383                False                polysaccharide biosynthesis protein
# 5384                False      peptide-methionine (S)-S-oxide reductase MsrA
# 5385                False                               hypothetical protein
# 5386                False                          30S ribosomal protein S20
#
#            Pfam_name    locus  characterized_function
# 0                NaN  RPA0001                    True
# 1                NaN  RPA0002                    True
# 2                NaN  RPA0003                    True
# 3                NaN  RPA0004                    True
# 4                NaN  RPA0005                    True
# 5     AsnC_trans_reg  RPA0006                    True
# 6             HWE_HK  RPA0007                    True
# 7              PAS_4  RPA0007                    True
# 8              PAS_8  RPA0007                    True
# 9                NaN  RPA0008                    True
# 10               NaN  RPA0009                    True
# 11    AsnC_trans_reg  RPA0010                    True
# 12     HTH_AsnC-type  RPA0010                    True
# 13               NaN  RPA0011                   False
# 14               NaN  RPA0012                    True
# 15               NaN  RPA0013                    True
# 16               NaN  RPA0014                    True
# 17               NaN  RPA0015                    True
# 18               NaN  RPA0016                    True
# 19               NaN  RPA0017                    True
# 20               NaN  RPA0018                    True
# 21               NaN  RPA0019                    True
# 22               NaN  RPA0020                    True
# 23         adh_short  RPA0021                    True
# 24              DSBA  RPA0022                    True
# 25               NaN  RPA0023                    True
# 26         adh_short  RPA0024                    True
# 27               NaN  RPA0025                    True
# 28             ATG22  RPA0026                    True
# 29               NaN  RPA0027                    True
# ...              ...      ...                     ...
# 5357            CrtC  RPA4811                    True
# 5358           MAPEG  RPA4812                    True
# 5359    Peripla_BP_6  RPA4813                    True
# 5360       OMP_b-brl  RPA4814                    True
# 5361          Omptin  RPA4814                    True
# 5362             NaN  RPA4815                    True
# 5363       HATPase_c  RPA4816                    True
# 5364    Response_reg  RPA4817                    True
# 5365     Trans_reg_C  RPA4817                    True
# 5366           PepSY  RPA4818                    True
# 5367             NaN  RPA4819                   False
# 5368             NaN  RPA4820                    True
# 5369             NaN  RPA4821                    True
# 5370          Fe-ADH  RPA4822                    True
# 5371     AMP-binding  RPA4823                    True
# 5372   AMP-binding_C  RPA4823                    True
# 5373            EthD  RPA4824                    True
# 5374          MerR_1  RPA4825                    True
# 5375             NaN  RPA4826                    True
# 5376     Zn-ribbon_8  RPA4827                    True
# 5377         DUF3551  RPA4828                   False
# 5378             NaN  RPA4829                    True
# 5379             NaN  RPA4830                    True
# 5380             NaN  RPA4831                   False
# 5381             NaN  RPA4832                    True
# 5382     Poly_export  RPA4833                    True
# 5383            SLBB  RPA4833                    True
# 5384             NaN  RPA4834                    True
# 5385             NaN  RPA4835                   False
# 5386             NaN  RPA4836                    True
#
# [5387 rows x 8 columns]

# %%
#now narrow down essential and unknown
def EssentialAndUnknown (row):
    essential = False
    if row['Essential_aerobic'] or row['Essential_phototrophic'] or row['Essential_longevity']:
        essential = True
    if (not row['characterized_function']) and essential:
        return True
    
df['Essential_unknown'] = df.apply(EssentialAndUnknown, axis=1)

#df[df.locus == 'RPA4831']
high_priority = df[df.Essential_unknown == True].copy()
high_priority.drop(['Essential_unknown', 'characterized_function'], axis=1, inplace=True)
#high_priority.to_csv("delme.txt", sep="\t")

# %%
#now merge in proteomics data
R_pal_file = "R_pal_aux_files\R_pal_LFQ_Foldchange.txt"
df_omics = pd.read_table(R_pal_file, sep="\t")
high_priority = high_priority.merge(df_omics, left_on='RefSeq', right_on='Protein IDs', how='left')
high_priority.drop('Protein IDs', axis=1, inplace=True)

# %%
high_priority.to_csv("delme2.txt", sep="\t")
